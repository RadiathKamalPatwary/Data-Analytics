# %% [markdown]
# # Data 200: Data Systems for Data Analytics (Spring 2026)

# %% [markdown]
# # Project 01

# %% [markdown]
# # Name: Radiath Kamal Patwary

# %%
import requests
import pandas as pd
import os
import numpy as np
from IPython.core.display import HTML
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ai_models_performance.csv")
df.head()
# Out:
#                          Model Context Window    Creator Intelligence Index  \
# 0              GPT-5.2 (xhigh)           400k     OpenAI                 51
# 1              Claude Opus 4.5           200k  Anthropic                 49
# 2  Gemini 3 Pro Preview (high)             1m     Google                 48
# 3               GPT-5.1 (high)           400k     OpenAI                 47
# 4               Gemini 3 Flash             1m     Google                 46
#
#   Price (Blended USD/1M Tokens)  Speed(median token/s)  \
# 0                        $4.81                     100
# 1                       $10.00                      79
# 2                        $4.50                     128
# 3                        $3.44                     127
# 4                        $1.13                     224
#
#    Latency (First Answer Chunk /s)
# 0                            44.29
# 1                             1.70
# 2                            32.19
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Model                            188 non-null    str
#  1   Context Window                   188 non-null    str
#  2   Creator                          188 non-null    str
#  3   Intelligence Index               188 non-null    str
#  4   Price (Blended USD/1M Tokens)    188 non-null    str
#  5   Speed(median token/s)            188 non-null    int64
#  6   Latency (First Answer Chunk /s)  188 non-null    float64
# dtypes: float64(1), int64(1), str(5)
# memory usage: 10.4 KB

# %%
df.describe(include="all")
# Out:
#                   Model Context Window  Creator Intelligence Index  \
# count               188            188      188                188
# unique              154             20       37                 64
# top     Claude Opus 4.5           128k  Alibaba                 15
# freq                  2             53       28                 11
# mean                NaN            NaN      NaN                NaN
# std                 NaN            NaN      NaN                NaN
# min                 NaN            NaN      NaN                NaN
# 25%                 NaN            NaN      NaN                NaN
# 50%                 NaN            NaN      NaN                NaN
# 75%                 NaN            NaN      NaN                NaN
# max                 NaN            NaN      NaN                NaN
#
#        Price (Blended USD/1M Tokens)  Speed(median token/s)  \
# count                            188             188.000000
# ...

# %%
grouped = df.groupby("Creator").agg({
    "Speed(median token/s)": "mean",
    "Latency (First Answer Chunk /s)": "mean",
    "Model": "count"
})

print(grouped)
# Out:
#                                        Speed(median token/s)  \
# Creator
# AI21 Labs                                          57.000000
# Alibaba                                            81.392857
# Allen Institute for AI                             50.000000
# Amazon                                            173.727273
# Anthropic                                          87.500000
# Baidu                                              13.500000
# ByteDance Seed                                      0.000000
# Cohere                                             58.000000
# Deep Cogito                                        74.000000
# DeepSeek                                           54.777778
# Google                                            148.500000
# IBM                                                39.833333
# InclusionAI                                        79.500000
# Kimi                                               45.333333
# ...

# %% [markdown]
# The aggregations show that different AI model creators have different strengths. Some creators have higher average speed, while others have lower average latency, meaning faster response times. The number of models also varies across creators, which shows that some companies produce more models than others.This suggests that there is no single creator that is best in every aspect. Instead, different companies focus on different priorities, such as speed, efficiency, or responsiveness. For example, a creator with high speed may not necessarily have low latency, and vice versa.

# %%
plt.scatter(df["Speed(median token/s)"], df["Latency (First Answer Chunk /s)"])

plt.xlabel("Speed (median token/s)")
plt.ylabel("Latency (First Answer Chunk /s)")
plt.title("Speed vs Latency of AI Models")

plt.show()

# %%
plt.hist(df["Speed(median token/s)"])

plt.xlabel("Speed (median token/s)")
plt.ylabel("Frequency")
plt.title("Distribution of Model Speed")

plt.show()
